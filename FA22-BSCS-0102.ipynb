# %% [markdown]
# # NOTEBOOK 01

# %% [markdown]
# ## Introduction
# In this notebook, we summarize important tools, languages, and libraries used by data scientists. We'll also include some examples of arithmetic expressions and demonstrate how to perform basic calculations using Python.

# %% [markdown]
# ## Languages Used in Data Science
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Popular Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Data Science Tools
#
# | Tool             | Description                |
# |------------------|----------------------------|
# | Jupyter Notebook | Interactive coding         |
# | RStudio          | IDE for R programming      |
# | Apache Spark     | Big data processing engine |
# | TensorFlow       | Deep learning library      |
# | RapidMiner       | Visual data science tool   |

# %% [markdown]
# ## Arithmetic Expressions
# This section demonstrates basic arithmetic operations such as addition and multiplication using Python.

# %%
result = (3 * 4) + 5
print("Result:", result)
# Out:
# Result: 17

# %%
minutes = 200
hours = minutes / 60
print("200 minutes is equal to", hours, "hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ## Objectives
# - List popular data science languages
# - List common libraries
# - Use markdown for documentation
# - Perform basic arithmetic in code
# - Convert time units in Python

# %% [markdown]
# **Author:** Muhammad Anas
